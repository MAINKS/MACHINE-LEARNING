# %% [markdown]
# #Project - Artificial Neural Network model based on Regression
#
# ### For a large dataset within a organisation working in Manufacturing field , using ANN implementation , predicting the Output - Electrical energy power as per the circumstances given under Pressure , Temperature & Humidity, Vaccum etc.

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_excel('Folds5x2_pp.xlsx')   #To read excel files using pandas , pd.read_excel is used
X = dataset.iloc[: , :-1].values
y = dataset.iloc[: , -1].values

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train, y_test = train_test_split(X,y , test_size=0.2 , random_state = 0)

print(X_train)
print('\n')
print(X_test)
print('\n')
print(y_train)
print('\n')
print(y_test)
# Out:
# [[  11.22   43.13 1017.24   80.9 ]
#  [  13.67   54.3  1015.92   75.42]
#  [  32.84   77.95 1014.68   45.8 ]
#  ...
#  [  16.81   38.52 1018.26   75.21]
#  [  12.8    41.16 1022.43   86.19]
#  [  32.32   67.9  1006.08   37.93]]
#
#
# [[  28.66   77.95 1009.56   69.07]
#  [  17.48   49.39 1021.51   84.53]
#  [  14.86   43.14 1019.21   99.14]
#  ...
#  [  12.24   44.92 1023.74   88.21]
#  [  27.28   47.93 1003.46   59.22]
#  [  17.28   39.99 1007.09   74.25]]
#
#
# [473.93 467.87 431.97 ... 459.01 462.72 428.12]
#
#
# [431.23 460.01 461.14 ... 473.26 438.   463.28]

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Initializing the ANN

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation= 'relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation= 'relu'))

# %% [markdown]
# ### Adding the output layer

# %%
ann.add(tf.keras.layers.Dense(units=1))

#No activation function required for the regression as o/p is numerical,
#only for classification, sigmoid (2 categories) or softmax(3 categories) activation fn it is required as we Obtain categorical data of larger scope

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %%
ann.compile(optimizer ='adam' , loss = 'mean_squared_error' , )

#mean_squared_error is loss fxn while implementing ANN in Regression , binary_crossentropy for classification

# %% [markdown]
# ### Training the ANN model on the Training set

# %%
ann.fit(X_train , y_train , batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4263
# Epoch 2/100
# 240/240 [==============================] - 1s 2ms/step - loss: 27.2117
# Epoch 3/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.8557
# Epoch 4/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.7661
# Epoch 5/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7633
# Epoch 6/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.4852
# Epoch 7/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.7948
# Epoch 8/100
# 240/240 [==============================] - 1s 4ms/step - loss: 26.9735
# Epoch 9/100
# 240/240 [==============================] - 1s 4ms/step - loss: 26.2921
# Epoch 10/100
# 240/240 [==============================] - 1s 4ms/step - loss: 27.2927
# Epoch 11/100
# 240/240 [==============================] - 1s 4ms/step - loss: 26.5583
# Epoch 12/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.7485
# Epoch 13/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4358
# Epoch 14/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4031
# Epoch 15/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.0679
# Epoch 16/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.3222
# Epoch 17/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7438
# Epoch 18/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6092
# Epoch 19/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5606
# Epoch 20/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3744
# Epoch 21/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5992
# Epoch 22/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7626
# Epoch 23/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6585
# Epoch 24/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.3129
# Epoch 25/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.2616
# Epoch 26/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8259
# Epoch 27/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5892
# Epoch 28/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8572
# Epoch 29/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.4452
# Epoch 30/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4451
# Epoch 31/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6193
# Epoch 32/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.7776
# Epoch 33/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7233
# Epoch 34/100
# 240/240 [==============================] - 1s 3ms/step - loss: 27.0553
# Epoch 35/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.5766
# Epoch 36/100
# 240/240 [==============================] - 1s 3ms/step - loss: 27.6833
# Epoch 37/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.9139
# Epoch 38/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.2821
# Epoch 39/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8974
# Epoch 40/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8578
# Epoch 41/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6530
# Epoch 42/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7036
# Epoch 43/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5370
# Epoch 44/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.2998
# Epoch 45/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7962
# Epoch 46/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8262
# Epoch 47/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.0119
# Epoch 48/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6378
# Epoch 49/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.2079
# Epoch 50/100
# 240/240 [==============================] - 1s 2ms/step - loss: 27.0339
# Epoch 51/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8366
# Epoch 52/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8123
# Epoch 53/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8520
# Epoch 54/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.9963
# Epoch 55/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5576
# Epoch 56/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8853
# Epoch 57/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.8660
# Epoch 58/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8769
# Epoch 59/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.2939
# Epoch 60/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.5565
# Epoch 61/100
# 240/240 [==============================] - 1s 3ms/step - loss: 27.0445
# Epoch 62/100
# 240/240 [==============================] - 1s 3ms/step - loss: 27.1825
# Epoch 63/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.4013
# Epoch 64/100
# 240/240 [==============================] - 1s 3ms/step - loss: 27.1270
# Epoch 65/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.3624
# Epoch 66/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.8182
# Epoch 67/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.2556
# Epoch 68/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8291
# Epoch 69/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3032
# Epoch 70/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7217
# Epoch 71/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8806
# Epoch 72/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5817
# Epoch 73/100
# 240/240 [==============================] - 1s 2ms/step - loss: 27.4792
# Epoch 74/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4887
# Epoch 75/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6901
# Epoch 76/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3231
# Epoch 77/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.0627
# Epoch 78/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3676
# Epoch 79/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3927
# Epoch 80/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3571
# Epoch 81/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.2150
# Epoch 82/100
# 240/240 [==============================] - 1s 2ms/step - loss: 27.0875
# Epoch 83/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.3099
# Epoch 84/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.2354
# Epoch 85/100
# 240/240 [==============================] - 0s 2ms/step - loss: 27.2341
# Epoch 86/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4316
# Epoch 87/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7259
# Epoch 88/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.4964
# Epoch 89/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.8295
# Epoch 90/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.8034
# Epoch 91/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.7755
# Epoch 92/100
# 240/240 [==============================] - 1s 3ms/step - loss: 26.2727
# Epoch 93/100
# 240/240 [==============================] - 1s 2ms/step - loss: 26.4238
# Epoch 94/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5944
# Epoch 95/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.8105
# Epoch 96/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5911
# Epoch 97/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.7266
# Epoch 98/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.6467
# Epoch 99/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.4990
# Epoch 100/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.5532

# %% [markdown]
# ### Predicting the results of the Test set

# %%
y_pred = ann.predict(X_test)

np.set_printoptions(precision = 2)   #numpy sets decimal point precison after 2 decimals
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))

print('\n')
print('Here we have our Predicted output')
print(y_pred)

#Our Artificial neural network predicted the values accurately , very close to real results
#In this way here prediction Of EP(Net hourly Electrical Energy Output) is predicted well by ANN for Manufacturing Company
# Out:
# 60/60 [==============================] - 0s 1ms/step
# [[431.22 431.23]
#  [462.72 460.01]
#  [466.06 461.14]
#  ...
#  [473.51 473.26]
#  [439.83 438.  ]
#  [459.19 463.28]]
#
#
# Here we have our Predicted output
# [[431.22]
#  [462.72]
#  [466.06]
#  ...
#  [473.51]
#  [439.83]
#  [459.19]]
